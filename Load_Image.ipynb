# %% [markdown]
# ### Loading Image Data
#
# This time we are going to work on full sized images. In this notebook, we will look at how to load images and use them to train neural networks.

# %% [markdown]
# We will use the cats and dogs dataset to train a neural network that can differentiate between cats and dogs.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms

import helper

# %% [markdown]
# ### How to load the images ?

# %%
# we will use datasets.ImageFolder
# define the directory
data_dir = 'Cat_Dog_data/train'

# Define the transform for the image set. Its included in the preprocessing
transform = transforms.Compose([transforms.Resize(255), 
                               transforms.CenterCrop(224),
                               transforms.ToTensor()])
# Generic data loader where data are arranged in the above data_dir format. And pass in
# transform
dataset = datasets.ImageFolder(data_dir, transform=transform)
# passing the dataset, batch size and shuffling into the dataloader
dataloader = torch.utils.data.DataLoader(dataset, batch_size = 32, shuffle=True)

# %%
# run this to test your data loadder
images, labels = next(iter(dataloader))
helper.imshow(images[0], normalize=False)

# %%
## Define transforms for training data and testing data below

# %%
data_dir = 'Cat_Dog_data'

# provide transformations on the images. More the transformation, more are
# the images, more the variations in the data. Here we will define the 
# various transformations
train_transform = transforms.Compose([
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
])
test_transform = transforms.Compose([transforms.Resize(255), 
                               transforms.CenterCrop(224),
                               transforms.ToTensor()])

train_dataset = datasets.ImageFolder(data_dir + '/train', transform=train_transform)
test_dataset = datasets.ImageFolder(data_dir + '/test', transform=test_transform)

trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
## Chnage this to the trainloader or testloader

data_iter = iter(testloader)

images, labels = next(data_iter)

fig, axes= plt.subplots(figsize=(10,4), ncols = 4)
for index in range(4):
    ax = axes[index]
    helper.imshow(images[index], ax = ax, normalize = False)
